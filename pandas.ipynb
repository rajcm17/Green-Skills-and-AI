# %%
print("Hello world!")
# Out:
# Hello world!

# %%
a= "hello world"
print(a)
# Out:
# hello world

# %%
from platform import python_version as p
print(p())
# Out:
# 3.8.8

# %%
a=4
b=2
c=a-b
print(c)
# Out:
# 2

# %%
x= input("enter the value for x:") 
y=input("enter the value for y: ")
# Out:
# enter the value for x:2313
# enter the value for y: 3213

# %%
p=int(input("enter the principal value:"))
t=int(input("enter the time duretion:"))
r=int(input("enter the rate of intrest:"))
v=(p*t*r)/100
print("I=",v)
# Out:
# enter the principal value:2
# enter the time duretion:12
# enter the rate of intrest:2
# I= 0.48

# %%
def say_hello():
    print("Hello ednet")

# %%
say_hello()

# %%
def add_num(num1,num2):
    return num1+num2

# %%
add_num(2,6)
# Out:
# 8

# %%
def demo(name,age):
    return name,age

# %%
demo("Basu",20)
# Out:
# ('Basu', 20)

# %%
x=lambda a:a+10
print(x(5))
# Out:
# 15

# %%
n= int(input("Enter the year: "))
leap=lambda y:(y%4==0 and y%100!=0) or y%400==0
if leap(n):
    print("Leap year")
else:
    print("Not leap year")
# Out:
# Enter the year: 2020
# Leap year

# %%
with open(r"C:\Users\HP\Desktop\abc.txt",'r') as myfile:
    content=myfile.read()
    print(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-102-80654843ae59> in <module>
# ----> 1 with open(r"C:\Users\HP\Desktop\abc.txt",'r') as myfile:
#       2     content=myfile.read()
#       3     print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\HP\\Desktop\\abc.txt'

# %%
with open(r"C:\Users\HP\Desktop\abc.txt",'w+') as myfile:
    myfile.write("VTU Belagavi and mysuru")

# %%
with open(r"C:\Users\HP\Desktop\abc.txt",'r') as myfile:
    content=myfile.read()
    print(content)

# %%
import os
os.rename("C:\\hi.txt", "a.txt")

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
empty_series = pd.Series()
print(empty_series)
# Out:
# Series([], dtype: float64)
# <ipython-input-9-ed063bcaa391>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty_series = pd.Series()

# %%
arr=np.array([22,33,44,55,66])
number_Series = pd.Series(arr)
print(number_Series)
# Out:
# 0    22
# 1    33
# 2    44
# 3    55
# 4    66
# dtype: int32

# %%
arr=np.array([1,2,3,4])
num_series=pd.Series(arr,index=['a','b','c','d'],name="num")
print(num_series)
# Out:
# a    1
# b    2
# c    3
# d    4
# Name: num, dtype: int32

# %%
data = {'Name':['Basu','Savitha','Prasad','Sanga'],
       'Age':[20,21,24,32]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0     Basu   20
# 1  Savitha   21
# 2   Prasad   24
# 3    Sanga   32

# %%
df
# Out:
#       Name  Age
# 0     Basu   20
# 1  Savitha   21
# 2   Prasad   24
# 3    Sanga   32

# %%
lists =[['Intel',20],['IBM',30],['MS',40]]
df1 = pd.DataFrame(lists)

# %%
df1
# Out:
#        0   1
# 0  Intel  20
# 1    IBM  30
# 2     MS  40

# %%
arr1 = np.random.randint(1,10, size=(3,5))
df2 = pd.DataFrame(arr1)

# %%
df2
# Out:
#    0  1  2  3  4
# 0  7  9  6  8  6
# 1  2  9  4  6  4
# 2  2  6  2  8  9

# %%
df3 = pd.read_csv(r"C:\Users\HP\Downloads\airlines.csv")
df3
# Out:
#      Airport.Code                                       Airport.Name  \
# 0             ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1             BOS                    Boston, MA: Logan International
# 2             BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3             CLT     Charlotte, NC: Charlotte Douglas International
# 4             DCA  Washington, DC: Ronald Reagan Washington National
# ...           ...                                                ...
# 4403          SAN             San Diego, CA: San Diego International
# 4404          SEA          Seattle, WA: Seattle/Tacoma International
# 4405          SFO     San Francisco, CA: San Francisco International
# 4406          SLC   Salt Lake City, UT: Salt Lake City International
# 4407          TPA                     Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 0       2003/06           6            June       2003
# ...

# %%
df3.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
df3.tail()
# Out:
#      Airport.Code                                      Airport.Name  \
# 4403          SAN            San Diego, CA: San Diego International
# 4404          SEA         Seattle, WA: Seattle/Tacoma International
# 4405          SFO    San Francisco, CA: San Francisco International
# 4406          SLC  Salt Lake City, UT: Salt Lake City International
# 4407          TPA                    Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 4403    2016/01           1         January       2016
# 4404    2016/01           1         January       2016
# 4405    2016/01           1         January       2016
# 4406    2016/01           1         January       2016
# 4407    2016/01           1         January       2016
#
#       Statistics.# of Delays.Carrier  Statistics.# of Delays.Late Aircraft  \
# 4403                             280                                   397
# ...

# %%
df3.tail(1)
# Out:
#      Airport.Code                    Airport.Name Time.Label  Time.Month  \
# 4407          TPA  Tampa, FL: Tampa International    2016/01           1
#
#      Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 4407         January       2016                             410
#
#       Statistics.# of Delays.Late Aircraft  \
# 4407                                   342
#
#       Statistics.# of Delays.National Aviation System  \
# 4407                                              312
#
#       Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 4407                                2  ...                        1095
#
#      Statistics.Flights.Diverted  Statistics.Flights.On Time  \
# 4407                           7                        4748
#
#       Statistics.Flights.Total  Statistics.Minutes Delayed.Carrier  \
# 4407                      5996                               22557
#
#       Statistics.Minutes Delayed.Late Aircraft  \
# ...

# %%
df4= pd.read_csv(r"C:\Users\HP\Downloads\airlines.csv",usecols=['Airport.Code','Airport.Name'])
df4.head()
# Out:
#   Airport.Code                                       Airport.Name
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...
# 1          BOS                    Boston, MA: Logan International
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...
# 3          CLT     Charlotte, NC: Charlotte Douglas International
# 4          DCA  Washington, DC: Ronald Reagan Washington National

# %%
df4= pd.read_csv(r"C:\Users\HP\Downloads\airlines.csv")
df4.head(10)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
# 5          DEN                   Denver, CO: Denver International    2003/06
# 6          DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...    2003/06
# 7          DTW            Detroit, MI: Detroit Metro Wayne County    2003/06
# 8          EWR           Newark, NJ: Newark Liberty International    2003/06
# 9          FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# ...

# %%
df4.shape
# Out:
# (4408, 24)

# %%
df4.iloc[[1,50]]
# Out:
#    Airport.Code                          Airport.Name Time.Label  Time.Month  \
# 1           BOS       Boston, MA: Logan International    2003/06           6
# 50          PDX  Portland, OR: Portland International    2003/07           7
#
#    Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 1             June       2003                             374
# 50            July       2003                             224
#
#     Statistics.# of Delays.Late Aircraft  \
# 1                                    495
# 50                                   332
#
#     Statistics.# of Delays.National Aviation System  \
# 1                                               685
# 50                                              126
#
#     Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 1                                 3  ...                        1623
# 50                                7  ...                         716
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
# ...

# %%
df4.describe()
# Out:
#         Time.Month    Time.Year  Statistics.# of Delays.Carrier  \
# count  4408.000000  4408.000000                     4408.000000
# mean      6.578947  2009.243421                      574.632486
# std       3.457890     3.667475                      329.616475
# min       1.000000  2003.000000                      112.000000
# 25%       4.000000  2006.000000                      358.000000
# 50%       7.000000  2009.000000                      476.000000
# 75%      10.000000  2012.000000                      692.000000
# max      12.000000  2016.000000                     3087.000000
#
#        Statistics.# of Delays.Late Aircraft  \
# count                           4408.000000
# mean                             789.078947
# std                              561.798420
# min                               86.000000
# 25%                              425.000000
# 50%                              618.500000
# 75%                              959.000000
# ...

# %%
df4.isnull().sum()
# Out:
# Airport.Code                                           0
# Airport.Name                                           0
# Time.Label                                             0
# Time.Month                                             0
# Time.Month Name                                        0
# Time.Year                                              0
# Statistics.# of Delays.Carrier                         0
# Statistics.# of Delays.Late Aircraft                   0
# Statistics.# of Delays.National Aviation System        0
# Statistics.# of Delays.Security                        0
# Statistics.# of Delays.Weather                         0
# Statistics.Carriers.Names                              0
# Statistics.Carriers.Total                              0
# Statistics.Flights.Cancelled                           0
# Statistics.Flights.Delayed                             0
# Statistics.Flights.Diverted                            0
# ...

# %%
df4.columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Time.Month',
#        'Time.Month Name', 'Time.Year', 'Statistics.# of Delays.Carrier',
#        'Statistics.# of Delays.Late Aircraft',
#        'Statistics.# of Delays.National Aviation System',
#        'Statistics.# of Delays.Security', 'Statistics.# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Statistics.Carriers.Total',
#        'Statistics.Flights.Cancelled', 'Statistics.Flights.Delayed',
#        'Statistics.Flights.Diverted', 'Statistics.Flights.On Time',
#        'Statistics.Flights.Total', 'Statistics.Minutes Delayed.Carrier',
#        'Statistics.Minutes Delayed.Late Aircraft',
#        'Statistics.Minutes Delayed.National Aviation System',
#        'Statistics.Minutes Delayed.Security',
#        'Statistics.Minutes Delayed.Total',
#        'Statistics.Minutes Delayed.Weather'],
#       dtype='object')

# %%
df4.dtypes
# Out:
# Airport.Code                                           object
# Airport.Name                                           object
# Time.Label                                             object
# Time.Month                                              int64
# Time.Month Name                                        object
# Time.Year                                               int64
# Statistics.# of Delays.Carrier                          int64
# Statistics.# of Delays.Late Aircraft                    int64
# Statistics.# of Delays.National Aviation System         int64
# Statistics.# of Delays.Security                         int64
# Statistics.# of Delays.Weather                          int64
# Statistics.Carriers.Names                              object
# Statistics.Carriers.Total                               int64
# Statistics.Flights.Cancelled                            int64
# Statistics.Flights.Delayed                              int64
# ...

# %%
df4["Airport.Code"]
# Out:
# 0       ATL
# 1       BOS
# 2       BWI
# 3       CLT
# 4       DCA
#        ...
# 4403    SAN
# 4404    SEA
# 4405    SFO
# 4406    SLC
# 4407    TPA
# Name: Airport.Code, Length: 4408, dtype: object

# %%
df4['Time.Month'] =df4['Time.Month'].astype('float')

# %%
df4['Time.Month'].dtypes
# Out:
# dtype('float64')

# %%
df4.rename(columns={'Airport.Code':'Acode'},inplace=True)

# %%
df4.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0         6.0            June       2003                            1009
# 1         6.0            June       2003                             374
# 2         6.0            June       2003                             296
# 3         6.0            June       2003                             300
# 4         6.0            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
df4['Airport.Name'].value_content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-55d03db2f42d> in <module>
# ----> 1 df4['Airport.Name'].value_content
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_content'

# %%
data1 = pd.DataFrame({'Name':['Basu','Savitha','Prasad','Sanga'],
       'Age':[20,21,24,32],
                     'Salary':[20000,23000,45000,53000]})
sorted1 = data1.sort_index(ascending=False)

# %%
sorted1
# Out:
#       Name  Age  Salary
# 3    Sanga   32   53000
# 2   Prasad   24   45000
# 1  Savitha   21   23000
# 0     Basu   20   20000

# %%
df_nba = pd.read_csv(r"C:\Users\HP\Downloads\nba.csv")
df_nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba.shape
# Out:
# (458, 9)

# %%
df_nba.loc[1:5, :]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0

# %%
df_nba.iloc[1:5, 0:2]
# Out:
#             Name            Team
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics

# %%
df_nba.rename(columns={'Name':'Player'},inplace=True)

# %%
df_nba.loc[1:5, 'Player' : 'Team']
# Out:
#           Player            Team
# 1    Jae Crowder  Boston Celtics
# 2   John Holland  Boston Celtics
# 3    R.J. Hunter  Boston Celtics
# 4  Jonas Jerebko  Boston Celtics
# 5   Amir Johnson  Boston Celtics

# %%
df_nba[df_nba['Team']=='Boston Celtics']
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
[df_nba['Team']=='Boston Celtics']
# Out:
# [0       True
#  1       True
#  2       True
#  3       True
#  4       True
#         ...
#  453    False
#  454    False
#  455    False
#  456    False
#  457    False
#  Name: Team, Length: 458, dtype: bool]

# %%
df_filter = df_nba[(df_nba['Team']=='Boston Celtics')&(df_nba['Age']<25)]
df_filter
# Out:
#              Player            Team  Number Position   Age Height  Weight  \
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 13      James Young  Boston Celtics    13.0       SG  20.0    6-6   215.0
#
#            College     Salary
# 3    Georgia State  1148640.0
# 6              LSU  1170960.0
# 8       Louisville  1824360.0
# 9   Oklahoma State  3431040.0
# 10      Ohio State  2569260.0
# 13        Kentucky  1749840.0

# %%
df_nba.query("College == 'Texas'")
# Out:
#                 Player                   Team  Number Position   Age Height  \
# 0        Avery Bradley         Boston Celtics     0.0       PG  25.0    6-2
# 66         Cory Joseph        Toronto Raptors     6.0       PG  24.0    6-3
# 133        P.J. Tucker           Phoenix Suns    17.0       SF  31.0    6-6
# 179   Tristan Thompson    Cleveland Cavaliers    13.0        C  25.0    6-9
# 208       Myles Turner         Indiana Pacers    33.0       PF  20.0   6-11
# 289    Jordan Hamilton   New Orleans Pelicans    25.0       SG  25.0    6-7
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
# 384      D.J. Augustin         Denver Nuggets    12.0       PG  28.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
#
#      Weight College      Salary
# 0     180.0   Texas   7730337.0
# 66    190.0   Texas   7000000.0
# 133   245.0   Texas   5500000.0
# 179   238.0   Texas  14260870.0
# 208   243.0   Texas   2357760.0
# ...

# %%
df_nba.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df_nba.isnull().sum().sum()
# Out:
# 104

# %%
cleaned_nba =df_nba.dropna(axis=0, how="any")
cleaned_nba
# Out:
#             Player            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
cleaned_nba.isnull().sum().sum()
# Out:
# 0

# %%
max_salary =df_nba['Salary'].max()

# %%
max_salary
# Out:
# 25000000.0

# %%
min_salary =df_nba['Salary'].min()

# %%
min_salary
# Out:
# 30888.0
